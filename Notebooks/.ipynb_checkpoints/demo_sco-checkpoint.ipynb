# %% [markdown]
# # FHIR SQL Builder

# %% [markdown]
# ## Retrieve FHIR resources via SQL statements

# %%
import pandas as pd
import intersystems_iris as iris
from sqlalchemy import create_engine,types

# %% [markdown]
# ## Create the SQL Alchemy engine

# %%
engine = create_engine('iris://SuperUser:SYS@uct_main1:1972/SC')
engine
# Out:
# Engine(iris://SuperUser:***@uct_main1:1972/SC)

# %% [markdown]
# ## Create the dbapi connection

# %%
host = "uct_main1"
port = 1972
namespace = "SC"
user = "_SYSTEM"
password = "SYS"

conn = iris.connect(
                    hostname=host, 
                    port=port, 
                    namespace=namespace, 
                    username=user, 
                    password=password
                   )

# create a cursor
cur = conn.cursor()
conn

# %%
pd.read_sql_table('Product', engine, schema="SC_Data")
# Out:
#     ID agingThreshold dataSource defaultUom description  gtin  \
# 0    1           None       None       None        None  None
# 1    2           None       None       None        None  None
# 2    3           None       None       None        None  None
# 3    4           None       None       None        None  None
# 4    5           None       None       None        None  None
# 5    6           None       None       None        None  None
# 6    7           None       None       None        None  None
# 7    8           None       None       None        None  None
# 8    9           None       None       None        None  None
# 9   10           None       None       None        None  None
# 10  11           None       None       None        None  None
# 11  12           None       None       None        None  None
# 12  13           None       None       None        None  None
# 13  14           None       None       None        None  None
# 14  15           None       None       None        None  None
# 15  16           None       None       None        None  None
# 16  17           None       None       None        None  None
# 17  18           None       None       None        None  None
#
#            lastUpdatedTime                   name productBrand  \
# 0  2022-11-15 00:19:01.171              iPhone 13        Apple
# 1  2022-11-15 00:19:01.171          iPhone 13 Pro        Apple
# 2  2022-11-15 00:19:01.171      iPhone 13 Pro Max        Apple
# 3  2022-11-15 00:19:01.171              iPad mini        Apple
# 4  2022-11-15 00:19:01.171                   iPad        Apple
# 5  2022-11-15 00:19:01.171               iPad Pro        Apple
# 6  2022-11-15 00:19:01.171   Apple Watch Series 3        Apple
# 7  2022-11-15 00:19:01.171         Apple Watch SE        Apple
# 8  2022-11-15 00:19:01.171   Apple Watch Series 6        Apple
# 9  2022-11-15 00:19:01.171           Apple A9 CPU         None
# 10 2022-11-15 00:19:01.171      iPhone 13 Battery         None
# 11 2022-11-15 00:19:01.171     iPhone memory chip         None
# 12 2022-11-15 00:19:01.171     iPhone memory 128G         None
# 13 2022-11-15 00:19:01.171     iPhone memory 256G         None
# 14 2022-11-15 00:19:01.171     iPhone memory 512G         None
# 15 2022-11-15 00:19:01.171  6.1 inch touch screen         None
# 16 2022-11-15 00:19:01.171  5.4 inch touch screen         None
# 17 2022-11-15 00:19:01.171  6.7 inch touch screen         None
#
#          productCategory productClass productFamily productNumber  \
# 0   Consumer electronics         None        iPhone          None
# 1   Consumer electronics         None        iPhone          None
# 2   Consumer electronics         None        iPhone          None
# 3   Consumer electronics         None          iPad          None
# 4   Consumer electronics         None          iPad          None
# 5   Consumer electronics         None   Apple Watch          None
# 6   Consumer electronics         None   Apple Watch          None
# 7   Consumer electronics         None   Apple Watch          None
# 8   Consumer electronics         None   Apple Watch          None
# 12 2022-11-15 00:19:00.991     Rio de Janeiro  Active
# 13 2022-11-15 00:19:00.991            Gauteng  Active
# 14 2022-11-15 00:19:00.991               None  Active
# 15 2022-11-15 00:19:00.991               None  Active
# 16 2022-11-15 00:19:00.991               None  Active
# 17 2022-11-15 00:19:00.991         Yamanashi   Active
# 18 2022-11-15 00:19:00.991          Shanghai   Active
# 19 2022-11-15 00:19:00.991  Chungcheongbuk-Do  Active
# 20 2022-11-15 00:19:00.991             Penang  Active
# 21 2022-11-15 00:19:00.991             Laguna  Active
# 22 2022-11-15 00:19:00.991            Drenthe  Active
# 23 2022-11-15 00:19:00.991    Baja California  Active
# 24 2022-11-15 00:19:00.991                 TX  Active
# 25 2022-11-15 00:19:00.991                 MA  Active
# 26 2022-11-15 00:19:00.991          Guangdong  Active
#
#                                         street       type            uid
# 0                       Robert-Bosch-Str. 16 a      Plant  LOC-PLANT-001
# 1         Plot No: A-1, Sipcot Industrial Park      Plant  LOC-PLANT-002
# 2                                         None  Warehouse   LOC-WARE-003
# 3                                         None  Warehouse   LOC-WARE-004
# 4                             7601 Penn Ave S.   Customer     LOC-CUST-1
# 5                               500 Staples Dr   Customer     LOC-CUST-2
# 6                              410 Terry Ave N   Customer     LOC-CUST-3
# 7                               208 S Akard St   Customer     LOC-CUST-4
# 8                                         None   Customer     LOC-CUST-5
# 9                    Friedrich-Ebert-Allee 140   Customer     LOC-CUST-6
# 10              Ronda de la Comunicaci��n, s/n   Customer     LOC-CUST-7
# 11                                        None   Customer     LOC-CUST-8
# 12                  Rua Humberto de Campos 425   Customer     LOC-CUST-9
# 13                             216 14th Avenue   Customer    LOC-CUST-10
# 14                           31 Jinrong Street   Customer    LOC-CUST-11
# 15               21 Jin Rong Jie Gong Yu G Zuo   Customer    LOC-CUST-12
# 16  2 Guangningbo St, Jin Rong Jie, Xicheng Qu   Customer    LOC-CUST-13
# 17                                        None   Supplier     LOC-SUPL-1
# 18                                        None   Supplier     LOC-SUPL-2
# 19                                        None   Supplier     LOC-SUPL-3
# 20                                        None   Supplier     LOC-SUPL-4
# 21                                        None   Supplier     LOC-SUPL-5
# 22                                        None   Supplier     LOC-SUPL-6
# 23                                        None   Supplier     LOC-SUPL-7
# 24                                        None   Supplier     LOC-SUPL-8
# 25                                        None   Supplier     LOC-SUPL-9
# 26                                        None   Supplier    LOC-SUPL-10

# %% [markdown]
# ## Store Location dataframe into IRIS AB.Location table

# %%
df.to_sql('Location', engine, schema="AB" ,if_exists='replace', index=True)
# Out:
# -1

# %% [markdown]
# ## Read AB.Location table from IRIS

# %%
pd.read_sql_table('Location', engine, schema="AB")
# Out:
#      index         City      County  Latitude  Longitude State   0-4   5-9  \
# 0        0     Abington    Plymouth   42.1047   -70.9458    MA  0.04  0.05
# 1        1        Acton   Middlesex   42.4850   -71.4333    MA  0.06  0.05
# 2        2     Acushnet     Bristol   41.6806   -70.9083    MA  0.06  0.05
# 3        3        Adams   Berkshire   42.6242   -73.1181    MA  0.04  0.04
# 4        4       Agawam     Hampden   42.0696   -72.6152    MA  0.06  0.04
# ..     ...          ...         ...       ...        ...   ...   ...   ...
# 345    345       Woburn   Middlesex   42.4791   -71.1518    MA  0.06  0.05
# 346    346    Worcester   Worcester   42.2667   -71.8000    MA  0.06  0.05
# 347    347  Worthington   Hampshire   42.3972   -72.9361    MA  0.02  0.05
# 348    348     Wrentham     Norfolk   42.0639   -71.3315    MA  0.07  0.06
# 349    349     Yarmouth  Barnstable   41.7055   -70.2286    MA  0.02  0.06
#
#      10-14  15-19  20-29  30-39  40-49  50-59  60-69  70-79   80+     F     M
# 0     0.05   0.07   0.13   0.14   0.14   0.16   0.12   0.07  0.03  0.51  0.49
# 1     0.07   0.11   0.07   0.09   0.16   0.19   0.10   0.07  0.03  0.52  0.48
# 2     0.04   0.04   0.12   0.11   0.13   0.18   0.13   0.11  0.03  0.52  0.48
# 3     0.05   0.04   0.16   0.12   0.12   0.15   0.16   0.07  0.05  0.48  0.52
# 4     0.06   0.05   0.10   0.10   0.13   0.17   0.14   0.09  0.06  0.51  0.49
# ..     ...    ...    ...    ...    ...    ...    ...    ...   ...   ...   ...
# 345   0.05   0.05   0.12   0.16   0.12   0.14   0.13   0.07  0.05  0.49  0.51
# 346   0.07   0.07   0.18   0.14   0.12   0.12   0.10   0.05  0.04  0.51  0.49
# 347   0.06   0.06   0.10   0.09   0.13   0.14   0.21   0.10  0.04  0.54  0.46
# 348   0.07   0.07   0.09   0.11   0.12   0.19   0.13   0.05  0.04  0.48  0.52
# 349   0.02   0.06   0.11   0.10   0.08   0.14   0.16   0.14  0.11  0.55  0.45
#
# [350 rows x 19 columns]

# %% [markdown]
# ## Crossjoin AAA.Patient and AB.Location

# %%
sql = """
SELECT 
P.*,Location.*
FROM AAA.Patient P
inner join AB.Location on P.BirthPlaceCity = Location.City
"""
cur.execute(sql)
cur.fetchall()
# Out:
# [Row(ID=51, AddressCity='Somerset', AddressCountry='US', AddressLine='360 Luettgen Run', AddressPostalCode='02725', AddressState='Massachusetts', BirthPlaceCity='Rowley', BirthPlaceCountry='US', BirthPlaceState='Massachusetts', FirstName='Frankie174', Gender='male', IdentifierCode='DL', IdentifierType=None, IdentifierValue='S99950276', Key='Patient/51', LastName='Jast432', LastUpdated='2024-06-25T20:26:03Z', index=252, City='Rowley', County='Essex', Latitude=42.7167, Longitude=-70.8792, State='MA', _23=0.03, _24=0.06, _25=0.05, _26=0.09, _27=0.09, _28=0.12, _29=0.11, _30=0.19, _31=0.14, _32=0.08, _33=0.04, F=0.54, M=0.46),
#  Row(ID=84, AddressCity='Swansea', AddressCountry='US', AddressLine='419 Crooks Pathway Apt 59', AddressPostalCode=None, AddressState='Massachusetts', BirthPlaceCity='Boxford', BirthPlaceCountry='US', BirthPlaceState='Massachusetts', FirstName='Gabriele201', Gender='female', IdentifierCode=None, IdentifierType=None, IdentifierValue=None, Key='Patient/84', LastName='Rohan584', LastUpdated='2024-06-25T20:26:03Z', index=38, City='Boxford', County='Essex', Latitude=42.6736, Longitude=-70.9861, State='MA', _23=0.05, _24=0.04, _25=0.14, _26=0.05, _27=0.05, _28=0.08, _29=0.15, _30=0.19, _31=0.16, _32=0.04, _33=0.05, F=0.49, M=0.51),
#  Row(ID=327, AddressCity='Boston', AddressCountry='US', AddressLine='725 Shields Knoll', AddressPostalCode='02109', AddressState='Massachusetts', BirthPlaceCity='Braintree', BirthPlaceCountry='US', BirthPlaceState='Massachusetts', FirstName='Margie619', Gender='female', IdentifierCode='DL', IdentifierType=None, IdentifierValue='S99981337', Key='Patient/327', LastName='Hettinger594', LastUpdated='2024-06-25T20:26:03Z', index=40, City='Braintree', County='Norfolk', Latitude=42.206, Longitude=-71.005, State='MA', _23=0.04, _24=0.06, _25=0.06, _26=0.07, _27=0.1, _28=0.14, _29=0.14, _30=0.15, _31=0.12, _32=0.07, _33=0.05, F=0.52, M=0.48),
#  Row(ID=3117, AddressCity='Shirley', AddressCountry='US', AddressLine='1081 Ward Key Unit 71', AddressPostalCode='01464', AddressState='Massachusetts', BirthPlaceCity='Newton', BirthPlaceCountry='US', BirthPlaceState='Massachusetts', FirstName='Jeanne', Gender='female', IdentifierCode='DL', IdentifierType=None, IdentifierValue='S99916528', Key='Patient/3117', LastName='DUBOIS', LastUpdated='2024-06-26T09:15:31Z', index=205, City='Newton', County='Middlesex', Latitude=42.3369, Longitude=-71.2097, State='MA', _23=0.05, _24=0.05, _25=0.07, _26=0.08, _27=0.13, _28=0.11, _29=0.12, _30=0.13, _31=0.13, _32=0.08, _33=0.05, F=0.54, M=0.46)]

# %% [markdown]
# ## Display the SQL Query from a dataframe

# %%
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#      ID AddressCity AddressCountry                AddressLine  \
# 0    51    Somerset             US           360 Luettgen Run
# 1    84     Swansea             US  419 Crooks Pathway Apt 59
# 2   327      Boston             US          725 Shields Knoll
# 3  3117     Shirley             US      1081 Ward Key Unit 71
#
#   AddressPostalCode   AddressState BirthPlaceCity BirthPlaceCountry  \
# 0             02725  Massachusetts         Rowley                US
# 1              None  Massachusetts        Boxford                US
# 2             02109  Massachusetts      Braintree                US
# 3             01464  Massachusetts         Newton                US
#
#   BirthPlaceState    FirstName  ... 15-19 20-29 30-39 40-49 50-59 60-69 70-79  \
# 0   Massachusetts   Frankie174  ...  0.09  0.09  0.12  0.11  0.19  0.14  0.08
# 1   Massachusetts  Gabriele201  ...  0.05  0.05  0.08  0.15  0.19  0.16  0.04
# 2   Massachusetts    Margie619  ...  0.07  0.10  0.14  0.14  0.15  0.12  0.07
# 3   Massachusetts       Jeanne  ...  0.08  0.13  0.11  0.12  0.13  0.13  0.08
#
#     80+     F     M
# 0  0.04  0.54  0.46
# 1  0.05  0.49  0.51
# 2  0.05  0.52  0.48
# 3  0.05  0.54  0.46
#
# [4 rows x 36 columns]

# %% [markdown]
# ## Display the AA.Observation data after having projected it using FHIR SQL Builder

# %% [markdown]
# ### Alternatively, you can import the misc/T1.json transformation file using FHIR SQL Builder

# %%
pd.read_sql_table('Patient', engine, schema="BOWMEDICAL")
# Out:
#      ID  Gender           Key PatientBirthDate  \
# 0    51    male    Patient/51       1975-08-12
# 1    84  female    Patient/84       2009-05-04
# 2    93  female    Patient/93       1945-12-19
# 3   166  female   Patient/166       1945-12-19
# 4   327  female   Patient/327       1995-03-26
# 5  3117  female  Patient/3117       1954-06-13
# 6  3162  female  Patient/3000       1956-01-29
#
#   PatientIdentifierTypeCodingDisplay PatientNameFamily PatientNameGiven
# 0                               None           Jast432       Frankie174
# 1                               None          Rohan584      Gabriele201
# 2                               None          Frami345        Kallie862
# 3                               None          Davis923          Lean294
# 4                               None      Hettinger594        Margie619
# 5                               None            DUBOIS           Jeanne
# 6                               None           HENDRIX          Barbara

# %% [markdown]
# ## Crossjoin AA.Patient and AA.Observation

# %%
sql = """
SELECT top 10
P.Key,P.FirstName,P.LastName,O.*
FROM AAA.Patient P
inner join AAA.Observation O on P.Key = O.SubjectReference
"""
cur.execute(sql)
cur.fetchall()
# Out:
# [Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=88, Code='cm', _5='Observation/88', ObservationCodeCodingCode='8302-2', ObservationCodeCodingDisplay='Body Height', QuantityValue='76.6', SubjectReference='Patient/84', System='http://unitsofmeasure.org', Unit='cm', Value='76.6'),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=89, Code='{score}', _5='Observation/89', ObservationCodeCodingCode='72514-3', ObservationCodeCodingDisplay='Pain severity - 0-10 verbal numeric rating [Score] - Reported', QuantityValue='4', SubjectReference='Patient/84', System='http://unitsofmeasure.org', Unit='{score}', Value='4'),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=90, Code='kg', _5='Observation/90', ObservationCodeCodingCode='29463-7', ObservationCodeCodingDisplay='Body Weight', QuantityValue='12.3', SubjectReference='Patient/84', System='http://unitsofmeasure.org', Unit='kg', Value='12.3'),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=91, Code='%', _5='Observation/91', ObservationCodeCodingCode='77606-2', ObservationCodeCodingDisplay='Weight-for-length Per age and sex', QuantityValue='98.841', SubjectReference='Patient/84', System='http://unitsofmeasure.org', Unit='%', Value='98.841'),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=92, Code=None, _5='Observation/92', ObservationCodeCodingCode='85354-9', ObservationCodeCodingDisplay='Blood Pressure', QuantityValue=None, SubjectReference='Patient/84', System=None, Unit=None, Value=None),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=95, Code=None, _5='Observation/95', ObservationCodeCodingCode='72166-2', ObservationCodeCodingDisplay='Tobacco smoking status NHIS', QuantityValue=None, SubjectReference='Patient/84', System=None, Unit=None, Value=None),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=101, Code='cm', _5='Observation/101', ObservationCodeCodingCode='8302-2', ObservationCodeCodingDisplay='Body Height', QuantityValue='81.4', SubjectReference='Patient/84', System='http://unitsofmeasure.org', Unit='cm', Value='81.4'),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=102, Code='{score}', _5='Observation/102', ObservationCodeCodingCode='72514-3', ObservationCodeCodingDisplay='Pain severity - 0-10 verbal numeric rating [Score] - Reported', QuantityValue='1', SubjectReference='Patient/84', System='http://unitsofmeasure.org', Unit='{score}', Value='1'),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=168, Code='kg', _5='Observation/168', ObservationCodeCodingCode='29463-7', ObservationCodeCodingDisplay='Body Weight', QuantityValue='13.3', SubjectReference='Patient/84', System='http://unitsofmeasure.org', Unit='kg', Value='13.3'),
#  Row(Key='Patient/84', FirstName='Gabriele201', LastName='Rohan584', ID=169, Code='%', _5='Observation/169', ObservationCodeCodingCode='77606-2', ObservationCodeCodingDisplay='Weight-for-length Per age and sex', QuantityValue='98.907', SubjectReference='Patient/84', System='http://unitsofmeasure.org', Unit='%', Value='98.907')]

# %% [markdown]
# ## Display the SQL Query from a dataframe

# %%
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#           Key   FirstName   LastName  ID     Code             Key  \
# 0  Patient/18  Carroll471  O'Hara248  42       cm  Observation/42
# 1  Patient/18  Carroll471  O'Hara248  43  {score}  Observation/43
# 2  Patient/18  Carroll471  O'Hara248  44       kg  Observation/44
# 3  Patient/18  Carroll471  O'Hara248  45    kg/m2  Observation/45
# 4  Patient/18  Carroll471  O'Hara248  46     None  Observation/46
#
#   ObservationCodeCodingCode  \
# 0                    8302-2
# 1                   72514-3
# 2                   29463-7
# 3                   39156-5
# 4                   85354-9
#
#                         ObservationCodeCodingDisplay QuantityValue  \
# 0                                        Body Height         193.3
# 1  Pain severity - 0-10 verbal numeric rating [Sc...             3
# 2                                        Body Weight         106.3
# 3                                    Body Mass Index         28.45
# 4                                     Blood Pressure          None
#
#   SubjectReference                     System     Unit  Value
# 0       Patient/18  http://unitsofmeasure.org       cm  193.3
# 1       Patient/18  http://unitsofmeasure.org  {score}      3
# 2       Patient/18  http://unitsofmeasure.org       kg  106.3
# 3       Patient/18  http://unitsofmeasure.org    kg/m2  28.45
# 4       Patient/18                       None     None   None

# %% [markdown]
# ## Create new table to store DriverLicense data

# %%
# execute a query
cur.execute("""create TABLE AB.DriverLicense (

    Code varchar(255) not null,
    Valid TINYINT not null

)""")
# Out:
# 0

# %% [markdown]
# ## DELETE DriverLicense data

# %%
cur.execute("""delete AB.DriverLicense""")
# Out:
# 3

# %% [markdown]
# ## INSERT DriverLicense data

# %%
cur.execute("""INSERT INTO AB.DriverLicense (Code, Valid) VALUES ('S99916528', 0)""")
cur.execute("""INSERT into AB.DriverLicense (Code, Valid) VALUES ('S99950276', 1)""")
cur.execute("""INSERT into AB.DriverLicense (Code, Valid) VALUES ('S99938125', 1)""")
# Out:
# 1

# %% [markdown]
# ## Display DriverLicense data

# %%
pd.read_sql_table('DriverLicense', engine, schema="AB",columns={"Code","Valid"})
# Out:
#    Valid       Code
# 0      0  S99916528
# 1      1  S99950276
# 2      1  S99938125

# %% [markdown]
# ## Crossjoin AA.Patient and AB.DriverLicense

# %%
sql = """
SELECT 
P.LastName,P.FirstName,P.IdentifierType,DL.*
FROM AAA.Patient P
inner join AB.DriverLicense DL on P.IdentifierValue = DL.Code
"""
cur.execute(sql)
cur.fetchall()
# Out:
# [Row(LastName='Jast432', FirstName='Frankie174', IdentifierType=None, Code='S99950276', Valid=1),
#  Row(LastName='Frami345', FirstName='Kallie862', IdentifierType=None, Code='S99938125', Valid=1),
#  Row(LastName='DUBOIS', FirstName='Jeanne', IdentifierType=None, Code='S99916528', Valid=0)]

# %% [markdown]
# ## Display the SQL Query from a dataframe

# %%
df = pd.read_sql_query(sql, engine)
df.head()
# Out:
#    LastName   FirstName IdentifierType       Code  Valid
# 0   Jast432  Frankie174           None  S99950276      1
# 1  Frami345   Kallie862           None  S99938125      1
# 2    DUBOIS      Jeanne           None  S99916528      0
